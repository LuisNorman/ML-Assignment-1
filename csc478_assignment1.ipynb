# %%
# Name: Luis Norman

# %%
import pandas as pd

# %%
df = pd.read_csv("bank_data.csv", index_col = 0)

# %%
df
# Out:
#          age    income  children  gender      region married  car  \
# id
# ID12101   48  17546.00         1  FEMALE  INNER_CITY      NO   NO
# ID12102   40  30085.10         3    MALE        TOWN     YES  YES
# ID12103   51  16575.40         0  FEMALE  INNER_CITY     YES  YES
# ID12104   23  20375.40         3  FEMALE        TOWN     YES   NO
# ID12105   57  50576.30         0  FEMALE       RURAL     YES   NO
# ...      ...       ...       ...     ...         ...     ...  ...
# ID12696   61  47025.00         2  FEMALE  INNER_CITY      NO  YES
# ID12697   30   9672.25         0  FEMALE  INNER_CITY     YES  YES
# ID12698   31  15976.30         0  FEMALE        TOWN     YES  YES
# ID12699   29  14711.80         0    MALE  INNER_CITY     YES   NO
# ID12700   38  26671.60         0    MALE        TOWN      NO  YES
#
#         savings_acct current_acct mortgage  pep
# id
# ID12101           NO           NO       NO  YES
# ID12102           NO          YES      YES   NO
# ...

# %%
# Q1. Show Explore the general characteristics
df_ssf = pd.get_dummies(df)
df_ssf.describe()
# Out:
#               age        income    children  gender_FEMALE  gender_MALE  \
# count  600.000000    600.000000  600.000000     600.000000   600.000000
# mean    42.395000  27524.031217    1.011667       0.500000     0.500000
# std     14.424947  12899.468246    1.056752       0.500417     0.500417
# min     18.000000   5014.210000    0.000000       0.000000     0.000000
# 25%     30.000000  17264.500000    0.000000       0.000000     0.000000
# 50%     42.000000  24925.300000    1.000000       0.500000     0.500000
# 75%     55.250000  36172.675000    2.000000       1.000000     1.000000
# max     67.000000  63130.100000    3.000000       1.000000     1.000000
#
#        region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN  \
# count         600.000000    600.000000       600.000000   600.000000
# mean            0.448333      0.160000         0.103333     0.288333
# std             0.497738      0.366912         0.304648     0.453365
# ...

# %%
# Q1. Show the distribustion amongst categorical variables
temp1 = df["gender"].value_counts()
temp2 = df["region"].value_counts()
temp3 = df["married"].value_counts()
temp4 = df["car"].value_counts()
temp5 = df["savings_acct"].value_counts()
temp6 = df["current_acct"].value_counts()
temp7 = df["mortgage"].value_counts()
temp8 = df["pep"].value_counts()

fig = plt.figure(figsize=(10,4))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Gender')
ax1.set_ylabel('Count')
ax1.set_title("Gender Distribution")
temp1.plot(kind='bar', grid = True)

ax1 = fig.add_subplot(122)
ax1.set_xlabel('Region')
ax1.set_ylabel('Count')
ax1.set_title("Region Distribution")
temp2.plot(kind='bar', grid = True)

# %%
temp3 = df["married"].value_counts()
temp4 = df["car"].value_counts()

fig = plt.figure(figsize=(10,4))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Married')
ax1.set_ylabel('Count')
ax1.set_title("Married Distribution")
temp3.plot(kind='bar', grid = True)

fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(122)
ax1.set_xlabel('Car')
ax1.set_ylabel('Count')
ax1.set_title("Car Distribution")
temp4.plot(kind='bar', grid = True)

# %%
temp5 = df["savings_acct"].value_counts()
temp6 = df["current_acct"].value_counts()

fig = plt.figure(figsize=(10,4))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Saving Account')
ax1.set_ylabel('Count')
ax1.set_title("Saving Account Distribution")
temp5.plot(kind='bar', grid = True)

ax1 = fig.add_subplot(122)
ax1.set_xlabel('Current Account')
ax1.set_ylabel('Count')
ax1.set_title("Current Account Distribution")
temp6.plot(kind='bar', grid = True)

# %%
temp7 = df["mortgage"].value_counts()
temp8 = df["pep"].value_counts()

fig = plt.figure(figsize=(10,4))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Mortgage')
ax1.set_ylabel('Count')
ax1.set_title("Mortgage Distribution")
temp7.plot(kind='bar', grid = True)

ax1 = fig.add_subplot(122)
ax1.set_xlabel('PEP')
ax1.set_ylabel('Count')
ax1.set_title("PEP Distribution")
temp8.plot(kind='bar', grid = True)
