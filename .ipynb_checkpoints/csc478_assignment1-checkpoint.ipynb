# %%
# Name: Luis Norman

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("bank_data.csv", index_col = 0)

# %%
# Q1. Explore the general characteristics of the data as a whole

# %%
# Show the characteristic of the numerical attributes
df.describe()
# Out:
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %%
# Show the distribution of categorical variables
df[["gender", "region", "married", "car", "savings_acct", "current_acct", "mortgage", "pep"]].describe().T
# Out:
#              count unique         top freq
# gender         600      2        MALE  300
# region         600      4  INNER_CITY  269
# married        600      2         YES  396
# car            600      2          NO  304
# savings_acct   600      2         YES  414
# current_acct   600      2         YES  455
# mortgage       600      2          NO  391
# pep            600      2          NO  326

# %%
# Q1. Show the distribustion amongst categorical variables
temp1 = df["gender"].value_counts()
temp2 = df["region"].value_counts()
temp3 = df["married"].value_counts()
temp4 = df["car"].value_counts()
temp5 = df["savings_acct"].value_counts()
temp6 = df["current_acct"].value_counts()
temp7 = df["mortgage"].value_counts()
temp8 = df["pep"].value_counts()

fig = plt.figure(figsize=(10,4))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Gender')
ax1.set_ylabel('Count')
ax1.set_title("Gender Distribution")
temp1.plot(kind='bar', grid = True)

ax1 = fig.add_subplot(122)
ax1.set_xlabel('Region')
ax1.set_ylabel('Count')
ax1.set_title("Region Distribution")
temp2.plot(kind='bar', grid = True)

# %%
temp3 = df["married"].value_counts()
temp4 = df["car"].value_counts()

fig = plt.figure(figsize=(10,4))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Married')
ax1.set_ylabel('Count')
ax1.set_title("Married Distribution")
temp3.plot(kind='bar', grid = True)

fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(122)
ax1.set_xlabel('Car')
ax1.set_ylabel('Count')
ax1.set_title("Car Distribution")
temp4.plot(kind='bar', grid = True)

# %%
temp5 = df["savings_acct"].value_counts()
temp6 = df["current_acct"].value_counts()

fig = plt.figure(figsize=(10,4))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Saving Account')
ax1.set_ylabel('Count')
ax1.set_title("Saving Account Distribution")
temp5.plot(kind='bar', grid = True)

ax1 = fig.add_subplot(122)
ax1.set_xlabel('Current Account')
ax1.set_ylabel('Count')
ax1.set_title("Current Account Distribution")
temp6.plot(kind='bar', grid = True)

# %%
temp7 = df["mortgage"].value_counts()
temp8 = df["pep"].value_counts()

fig = plt.figure(figsize=(10,4))

ax1 = fig.add_subplot(121)
ax1.set_xlabel('Mortgage')
ax1.set_ylabel('Count')
ax1.set_title("Mortgage Distribution")
temp7.plot(kind='bar', grid = True)

ax1 = fig.add_subplot(122)
ax1.set_xlabel('PEP')
ax1.set_ylabel('Count')
ax1.set_title("PEP Distribution")
temp8.plot(kind='bar', grid = True)

# %%
# Q2. Suppose that the hypothetical bank is particularly interested in customers who buy 
# the PEP (Personal Equity Plan) product. Compare and contrast the subsets of customers
# who buy and don't buy the PEP. Compute summaries (as in part 1) of the selected data
# with respect to all other attributes (you do not need to plot distributions). Can you 
# observe any significant differences between these segments of customers? Discuss your
# observations.

# %%
# Continuous attributes comparision
df.groupby("pep").describe().T
# Out:
# pep                       NO           YES
# age      count    326.000000    274.000000
#          mean      40.098160     45.127737
#          std       14.123506     14.327991
#          min       18.000000     18.000000
#          25%       27.000000     34.000000
#          50%       40.000000     45.000000
#          75%       51.000000     58.000000
#          max       67.000000     67.000000
# income   count    326.000000    274.000000
#          mean   24900.953374  30644.919453
#          std    11661.123422  13609.613043
#          min     5014.210000   7756.360000
#          25%    15366.475000  19639.475000
#          50%    23105.000000  28080.050000
#          75%    31210.900000  38458.350000
#          max    61554.600000  63130.100000
# children count    326.000000    274.000000
#          mean       1.067485      0.945255
#          std        1.195524      0.860571
#          min        0.000000      0.000000
#          25%        0.000000      0.000000
# ...

# %%
# Continuous and catagorical attributes comparison
# Had to convert the categorical variables to object type in order to compare them.
df["region"].astype("object").groupby("pep").describe().T
# Out:
# pep                          NO         YES
# age          count          326         274
#              unique          49          50
#              top             27          64
#              freq            12          13
# income       count          326         274
#              unique         325         274
#              top        38248.3     58367.3
#              freq             2           1
# children     count          326         274
#              unique           4           4
#              top              0           1
#              freq           167         110
# gender       count          326         274
#              unique           2           2
#              top         FEMALE        MALE
#              freq           170         144
# region       count          326         274
#              unique           4           4
#              top     INNER_CITY  INNER_CITY
#              freq           146         123
# ...

# %% [markdown]
# <h4>
# Less people tend to buy the PEP and if they do, they are on average 5 years older. Also, the ones that do have a PEP, tend to also have a higher average income.
# <br><br>
# Although men bought more PEP, it wasn't a significant big of a different. Out of 274 people who bought PEP, 144 were male and 130 were women.
# </h4>

# %%
# Q3 Use z-score normalization to standardize the values of the income attribute. 
# [Do not change the original income attribute in the table.]

# %%
# df_income = df[["income"]]
# df_income
zscore = lambda x: (x - x.mean()) / x.std()
df_income_std = df[["income"]].apply(zscore)
df_income_std
# Out:
#            income
# id
# ID12101 -0.773523
# ID12102  0.198541
# ID12103 -0.848766
# ID12104 -0.554180
# ID12105  1.787071
# ...           ...
# ID12696  1.511765
# ID12697 -1.383916
# ID12698 -0.895210
# ID12699 -0.993237
# ID12700 -0.066083
#
# [600 rows x 1 columns]

# %%
# Q4 Discretize the age attribute into 3 categories 
#(corresponding to "young", "mid-age", and "old"). 
# [Do not change the original age attribute in the table.]

# %%
df_age_discretize = pd.qcut(df.age, [0, .33, .66, 1], labels=["young", "mid-age", "old"])
df_age_discretize.head(10)
# Out:
# id
# ID12101    mid-age
# ID12102    mid-age
# ID12103        old
# ID12104      young
# ID12105        old
# ID12106        old
# ID12107      young
# ID12108        old
# ID12109    mid-age
# ID12110        old
# Name: age, dtype: category
# Categories (3, object): [young < mid-age < old]

# %%
# Q5 Go back to the original data (before the transforamtions in parts 3 and 4 above)
# and use Min-Max Normalization to transform the values of all numeric attributes 
# (income, age, children) in the original table onto the range 0.0-1.0.

# %%
df_numeric = df[["age", "income", "children"]]
df_norm = (df_numeric - df_numeric.min()) / (df_numeric.max() - df_numeric.min())
df_norm
# Out:
#               age    income  children
# id
# ID12101  0.612245  0.215634  0.333333
# ID12102  0.448980  0.431395  1.000000
# ID12103  0.673469  0.198933  0.000000
# ID12104  0.102041  0.264320  1.000000
# ID12105  0.795918  0.783987  0.000000
# ...           ...       ...       ...
# ID12696  0.877551  0.722880  0.666667
# ID12697  0.244898  0.080151  0.000000
# ID12698  0.265306  0.188625  0.000000
# ID12699  0.224490  0.166866  0.000000
# ID12700  0.408163  0.372659  0.000000
#
# [600 rows x 3 columns]

# %%
# Q6 Convert the table (after normalization in part 5) into the standard spreadsheet 
# format Note that this requires converting each categorical attribute into multiple  
# binary("dummy") attributes (one for each values of the categorical attribute) and  
# assigning binary values corresponding to the presence or not presence of the
# attribute value in  the original record). The numeric attributes should remain  
# unchanged.Save this new table into a file called bank_numeric.csv and submit it 
# along with your assignment. [Hint: you might consider using the get_dummies for 
# Pandas data frames.]

# %%
# Convert the table to standard spreadsheet format to get the numerical ll attributes
df_ssf = pd.get_dummies(df)
df_ssf.describe().T
# Out:
#                    count          mean           std      min      25%  \
# age                600.0     42.395000     14.424947    18.00     30.0
# income             600.0  27524.031217  12899.468246  5014.21  17264.5
# children           600.0      1.011667      1.056752     0.00      0.0
# gender_FEMALE      600.0      0.500000      0.500417     0.00      0.0
# gender_MALE        600.0      0.500000      0.500417     0.00      0.0
# region_INNER_CITY  600.0      0.448333      0.497738     0.00      0.0
# region_RURAL       600.0      0.160000      0.366912     0.00      0.0
# region_SUBURBAN    600.0      0.103333      0.304648     0.00      0.0
# region_TOWN        600.0      0.288333      0.453365     0.00      0.0
# married_NO         600.0      0.340000      0.474104     0.00      0.0
# married_YES        600.0      0.660000      0.474104     0.00      0.0
# car_NO             600.0      0.506667      0.500373     0.00      0.0
# ...

# %%
# Using the data set with the dummy variables (of the previous part), perform basic 
# correlation analysis among the attributes. Discuss your results by indicating any 
# significant positive or negative correlations among pairs of attributes. You need to 
# construct a complete Correlation Matrix. Be sure to first remove the Customer ID column 
# before creating the correlation matrix. [Hint: you can create the correlation matrix by 
# using the corr() function in Pandas or corrcoef function in NumPy].

# %%
corr_matrix = df_ssf.corr()
corr_matrix
# used to see if the correlation between any two objects are greater that 0.5 or -0.5
#temp = corr_matrix[corr_matrix>0.5]
#temp
# temp = corr_matrix[corr_matrix<-0.5]
# temp
# Out:
#                         age    income  children  gender_FEMALE  gender_MALE  \
# age                1.000000  0.752726  0.023572       0.090081    -0.090081
# income             0.752726  1.000000  0.036761       0.023845    -0.023845
# children           0.023572  0.036761  1.000000       0.014206    -0.014206
# gender_FEMALE      0.090081  0.023845  0.014206       1.000000    -1.000000
# gender_MALE       -0.090081 -0.023845 -0.014206      -1.000000     1.000000
# region_INNER_CITY -0.025171 -0.047564 -0.051222      -0.023459     0.023459
# region_RURAL       0.018635  0.084776  0.089902      -0.009092     0.009092
# region_SUBURBAN    0.031345  0.029824 -0.014122      -0.010951     0.010951
# region_TOWN       -0.008510 -0.036431 -0.007033       0.040472    -0.040472
# married_NO        -0.010394  0.008386  0.048716       0.021110    -0.021110
# married_YES        0.010394 -0.008386 -0.048716      -0.021110     0.021110
# ...

# %% [markdown]
# Observations: <br>1. Income seems to correlate with age.<br> <br>2. There are some correlation values that are considerably low (less than -0.5) but the they because the correlation is computed between another option within that category. For instance, the correlation value between male and female is -1 and that is because there is a pure negative correlation between them meaning if an object is identified as female, it can't be male. This is not interesting. <br>

# %%
# Q8. Using Matplotlib library and/or ploting capabilties of Pandas, create a scatter plot 
# of the (non-normalized) Income attribute relative to Age. Be sure that your plot 
# contains appropriate labels for the axes. Do these variables seem correlated?

# %%
df.plot(x="income", y="age", kind = "scatter")

# %%
# Q9. Create histograms for (non-normalized) Income (using 9 bins) and Age (using 15 bins).

# %%
plt.hist(df["income"], bins = 9)
plt.xlabel('Income')
plt.ylabel('Count')
plt.title('Histogram of Income Distribution')
plt.grid(True)

# %%
plt.hist(df["age"], bins = 9)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Histogram of Age Distribution')
plt.grid(True)

# %%
# Q10. Using a bargraph, plot the distribution of the values of the region attribute.

# %%
fig = plt.figure(figsize=(10,4))
temp2 = df["region"].value_counts()
ax1 = fig.add_subplot(122)
ax1.set_xlabel('Region')
ax1.set_ylabel('Count')
ax1.set_title("Region Distribution")
temp2.plot(kind='bar', grid = True)

# %%
# Q11. Perform a cross-tabulation of the region attribute with the pep attribute. 
# This requires the aggregation of the occurrences of each pep value (yes or no)
# separately for each value of the region attribute. Show the results as a 4 by 2 
# (region x pep) table with entries representing the counts. [Hint: you can either 
# use Numpy or use aggregations fucntions in Pandas such as groupby() and  cross-tab().] 
# Then, either using Matplotlib directly or the plot() function in Pandas create a bar
# chart graph to visualize of the relationships between these sets of variables. 
# [Hint: This example of creating simple bar charts using Matplotlib may be useful.]

# %%
# Perform a cross-tabulation
gg = pd.crosstab(df["region"], df["pep"])
gg
# Out:
# pep          NO  YES
# region
# INNER_CITY  146  123
# RURAL        50   46
# SUBURBAN     28   34
# TOWN        102   71

# %%
# Plot the cross-tabulation
gg.plot.bar(stacked=True)
